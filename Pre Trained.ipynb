# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras import layers
from matplotlib import pyplot as plt
import seaborn as sns

# %%
credit_data = pd.read_csv('creditcard.csv')

# %%
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_data.Class.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn.preprocessing import LabelEncoder
credit_data[['V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28']].apply(LabelEncoder().fit_transform)
# Out:
#             V1      V2      V3      V4      V5      V6      V7      V8  \
# 0        44928  120599  270851  243083  105668  211710  167150  159663
# 1       190308  160391  134835  182525  151841  161430  120001  155852
# 2        44982   28959  251918  175559   87589  253515  227985  194133
# 3        67135  107605  252751   68890  143700  244170  166825  214475
# 4        55018  212082  240745  177861   97922  181139  207795   54735
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 284802     581  275593     270   16342     836    1621    1093  275525
# 284803   86026  122771  260722   79680  225510  239000  134669  202380
# 284804  236109   96082    5048   97736  268453  261587   95134  244929
# 284805  128561  182906  180282  202324  101185  221246   54711  242910
# 284806  103431  107101  180358  102694  143457   84666  265094   32387
#
#             V9     V10  ...     V19     V20     V21     V22     V23     V24  \
# 0       185803  169841  ...  199265  228524  140442  174834   90634  147486
# 1       112665  125034  ...  113790  132797   68639   54299  190891   72302
# 2        20473  184645  ...    1783  251790  223177  233865  269516   36866
# 3        24537  144244  ...   17895   70472  108399  136591   60398   13166
# 4       222386  227847  ...  237769  244940  143568  236625   79502  163439
# ...        ...     ...  ...     ...     ...     ...     ...     ...     ...
# 284802  264372  273915  ...   47305  269094  213818  151931  270386   47379
# 284803  206049   31139  ...    9279  183275  214037  248406  151105   20037
# 284804  192469   75953  ...   56575  162310  218896  211936  125608  238464
# 284805  188614   87321  ...  274633  203621  227498  236791   69699  160730
# 284806  197504   34991  ...   95818  242946  226477  219426  253697  127819
#
#            V25     V26     V27     V28
# 0       160454  105171  218749  102230
# 1       168529  179871  126158  142841
# 2        68122  117706   81907   61165
# 3       253297   96705  191339  195684
# 4        94807  232984  235552  255032
# ...        ...     ...     ...     ...
# 284802  274473  207543  272884  274268
# 284803   28259   54217  194562   68033
# 284804  189774  131236  139638   97284
# 284805   31765  236451  211636  220460
# 284806   43639    7506  132748  141017
#
# [284807 rows x 28 columns]

# %%
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
X = credit_data.drop(['Class'], axis = 1)
Y = credit_data['Class']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()

print(X,Y)
X, Y = smote.fit_resample(X, Y)
print(X,Y)
# Out:
# 'from imblearn.over_sampling import SMOTE\n\nsmote = SMOTE()\n\nprint(X,Y)\nX, Y = smote.fit_resample(X, Y)\nprint(X,Y)'

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

models = {}

models['Logistic Regression'] = LogisticRegression(max_iter = 100000)

models['Support Vector Machines'] = LinearSVC(max_iter=100000, dual = False)
 
models['Decision Trees'] = DecisionTreeClassifier()

models['Random Forest'] = RandomForestClassifier()

models['Naive Bayes'] = GaussianNB()

models['K-Nearest Neighbour'] = KNeighborsClassifier()

models['Xgboost'] = XGBClassifier()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, classification_report, roc_curve, confusion_matrix

accuracy, precision, recall = {}, {}, {}

def execute_model(models, key):
    models[key].fit(x_train, y_train)

    predictions = models[key].predict(x_test)

    accuracy[key] = accuracy_score(predictions, y_test)
    precision[key] = precision_score(predictions, y_test)
    recall[key] = recall_score(predictions, y_test)
    auc = roc_auc_score(y_test,predictions)
    print('Classification Report:', key)
    print(classification_report(y_test, predictions))
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, predictions)
    print('ROC_AUC_SCORE is', auc)


    plt.plot(false_positive_rate, true_positive_rate)
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.title('ROC curve')
    plt.show()
    sns.heatmap(confusion_matrix(y_test, predictions), fmt='', annot=True)

# %%
execute_model(models, 'Logistic Regression')
# Out:
# Classification Report: Logistic Regression
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.93      0.64      0.76       101
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.82      0.88     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC_AUC_SCORE is 0.8217382113512525

# %%
execute_model(models, 'Support Vector Machines')
# Out:
# Classification Report: Support Vector Machines
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.85      0.47      0.60       101
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.73      0.80     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC_AUC_SCORE is 0.7326029203402217

# %%
execute_model(models, 'Decision Trees')
# Out:
# Classification Report: Decision Trees
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.78      0.74      0.76       101
#
#     accuracy                           1.00     56962
#    macro avg       0.89      0.87      0.88     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC_AUC_SCORE is 0.87110246787328

# %%
execute_model(models, 'Random Forest')
# Out:
# Classification Report: Random Forest
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.93      0.77      0.84       101
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.89      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC_AUC_SCORE is 0.8860858536215029

# %%
execute_model(models, 'Naive Bayes')
# Out:
# Classification Report: Naive Bayes
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56861
#            1       0.15      0.67      0.24       101
#
#     accuracy                           0.99     56962
#    macro avg       0.57      0.83      0.62     56962
# weighted avg       1.00      0.99      0.99     56962
#
# ROC_AUC_SCORE is 0.8331602809073577

# %%
execute_model(models, 'K-Nearest Neighbour')
# Out:
# Classification Report: K-Nearest Neighbour
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       1.00      0.04      0.08       101
#
#     accuracy                           1.00     56962
#    macro avg       1.00      0.52      0.54     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC_AUC_SCORE is 0.5198019801980198

# %%
execute_model(models, 'Xgboost')
# Out:
# Classification Report: Xgboost
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.94      0.79      0.86       101
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.90      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC_AUC_SCORE is 0.8959956370938266
